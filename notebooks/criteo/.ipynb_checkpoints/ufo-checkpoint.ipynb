# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import subprocess
import os

# %%
path = "/home/miguel/my_project_python/my_project_env/tfm/datasets/criteo"
os.chdir(path)

# %%
# Load in our data
df = pd.read_csv('Criteo_GA.csv', sep = ";")

# %%
df.head(5)
# Out:
#    Conversiones Valor de las conversiones             Path_1  \
# 0          4657               62.004,30 €       google / cpc
# 1          1500               20.332,41 €      google / cpc
# 2          1144               26.590,61 €   google / organic
# 3           904               18.503,30 €      google / cpc
# 4           810               23.361,69 €  (direct) / (none)
#
#                Path_2 Path_3 Path_4 Path_5 Path_6 Path_7 Path_8  ... Path_65  \
# 0                 NaN    NaN    NaN    NaN    NaN    NaN    NaN  ...     NaN
# 1        google / cpc    NaN    NaN    NaN    NaN    NaN    NaN  ...     NaN
# 2                 NaN    NaN    NaN    NaN    NaN    NaN    NaN  ...     NaN
# 3   (direct) / (none)    NaN    NaN    NaN    NaN    NaN    NaN  ...     NaN
# 4                 NaN    NaN    NaN    NaN    NaN    NaN    NaN  ...     NaN
#
#   Path_66 Path_67 Path_68 Path_69 Path_70 Path_71 Path_72 Path_73 Path_74
# ...

# %%
df.columns
# Out:
# Index(['Conversiones', 'Valor de las conversiones', 'Path_1', 'Path_2',
#        'Path_3', 'Path_4', 'Path_5', 'Path_6', 'Path_7', 'Path_8', 'Path_9',
#        'Path_10', 'Path_11', 'Path_12', 'Path_13', 'Path_14', 'Path_15',
#        'Path_16', 'Path_17', 'Path_18', 'Path_19', 'Path_20', 'Path_21',
#        'Path_22', 'Path_23', 'Path_24', 'Path_25', 'Path_26', 'Path_27',
#        'Path_28', 'Path_29', 'Path_30', 'Path_31', 'Path_32', 'Path_33',
#        'Path_34', 'Path_35', 'Path_36', 'Path_37', 'Path_38', 'Path_39',
#        'Path_40', 'Path_41', 'Path_42', 'Path_43', 'Path_44', 'Path_45',
#        'Path_46', 'Path_47', 'Path_48', 'Path_49', 'Path_50', 'Path_51',
#        'Path_52', 'Path_53', 'Path_54', 'Path_55', 'Path_56', 'Path_57',
#        'Path_58', 'Path_59', 'Path_60', 'Path_61', 'Path_62', 'Path_63',
#        'Path_64', 'Path_65', 'Path_66', 'Path_67', 'Path_68', 'Path_69',
#        'Path_70', 'Path_71', 'Path_72', 'Path_73', 'Path_74'],
#       dtype='object')

# %%
columns_interest = ['Path_1', 'Path_2', 'Path_3', 'Path_4', 'Path_5', 
                    'Path_6', 'Path_7', 'Path_8', 'Path_9', 'Path_10', 
                    'Path_11', 'Path_12', 'Path_13', 'Path_14', 'Path_15', 
                    'Path_16', 'Path_17', 'Path_18', 'Path_19', 'Path_20', 
                    'Path_21', 'Path_22', 'Path_23', 'Path_24', 'Path_25', 
                    'Path_26', 'Path_27', 'Path_28', 'Path_29', 'Path_30', 
                    'Path_31', 'Path_32', 'Path_33', 'Path_34', 'Path_35', 
                    'Path_36', 'Path_37', 'Path_38', 'Path_39', 'Path_40', 
                    'Path_41', 'Path_42', 'Path_43', 'Path_44', 'Path_45', 
                    'Path_46', 'Path_47', 'Path_48', 'Path_49', 'Path_50', 
                    'Path_51', 'Path_52', 'Path_53', 'Path_54', 'Path_55', 
                    'Path_56', 'Path_57', 'Path_58', 'Path_59', 'Path_60', 
                    'Path_61', 'Path_62', 'Path_63', 'Path_64', 'Path_65', 
                    'Path_66', 'Path_67', 'Path_68', 'Path_69', 'Path_70', 
                    'Path_71', 'Path_72', 'Path_73', 'Path_74']
df = df[columns_interest]

# %%
# Grab list of columns to iterate through
cols = df.columns

# %%
# Iterate through columns to change all ints to str and remove any trailing '.0'
for col in cols:
    df[col] = df[col].astype(str)
    #df[col] = df[col].map(lambda x: str(x)[:-2] if '.' in x else str(x))
    
# NO HACE FALTA

# %%
# Create a total path variable
df['Path'] = ''
for i in df.index:
    #df.at[i, 'Path'] = 'Start'
    for x in cols:
        df.at[i, 'Path'] = df.at[i, 'Path'] + df.at[i, x] + ' > '

# %%
df.head(5)
# Out:
#               Path_1              Path_2 Path_3 Path_4 Path_5 Path_6 Path_7  \
# 0       google / cpc                 nan    nan    nan    nan    nan    nan
# 1      google / cpc         google / cpc    nan    nan    nan    nan    nan
# 2   google / organic                 nan    nan    nan    nan    nan    nan
# 3      google / cpc    (direct) / (none)    nan    nan    nan    nan    nan
# 4  (direct) / (none)                 nan    nan    nan    nan    nan    nan
#
#   Path_8 Path_9 Path_10  ... Path_66 Path_67 Path_68 Path_69 Path_70 Path_71  \
# 0    nan    nan     nan  ...     nan     nan     nan     nan     nan     nan
# 1    nan    nan     nan  ...     nan     nan     nan     nan     nan     nan
# 2    nan    nan     nan  ...     nan     nan     nan     nan     nan     nan
# 3    nan    nan     nan  ...     nan     nan     nan     nan     nan     nan
# 4    nan    nan     nan  ...     nan     nan     nan     nan     nan     nan
#
# ...

# %%
df.shape
# Out:
# (1230, 75)
