# %% [markdown]
# # HACER INIT CON LA CARGA DEL ARCHIVO Y PEGARLO TAMBIEN EN CO1

# %% [markdown]
# # REVISAR
#
# # BW
#
# In this notebook, I am going to merge work with BW dataset that contains following column information:
#     - Reference
#     - Date
#     - Pageviews

# %%
from datetime import datetime
import numpy as np
import pandas as pd
import io #IO SIRVE?
import os

# %%
path = "/media/sf_Carpeta/Smart_Shopping/Data/BW"
os.chdir(path)

# %%
pwd
# Out:
# '/media/sf_Carpeta/Smart_Shopping/Data/BW'

# %%
df_bw = pd.read_excel("BW.xlsx", sheet_name="BW")

# %%
df_bw.head(5)
# Out:
#    Referencia                                    Name T Día natural  \
# 0        4623  ESPEJO PUERTA "LCC" BLANCO POLIETILENO    11.09.2017
# 1        4623  ESPEJO PUERTA "LCC" BLANCO POLIETILENO    21.09.2017
# 2        4623  ESPEJO PUERTA "LCC" BLANCO POLIETILENO    08.10.2017
# 3        4623  ESPEJO PUERTA "LCC" BLANCO POLIETILENO    16.10.2017
# 4        4623  ESPEJO PUERTA "LCC" BLANCO POLIETILENO    21.10.2017
#
#    Valor neto pedidos  Cantidad en unidades (pedidos)
# 0               18.93                               1
# 1               18.93                               1
# 2               16.08                               1
# 3               16.08                               1
# 4               16.08                               1

# %%
df_bw = df_bw.rename(index=str, columns={"Referencia":"Reference", "T Día natural": "Date", "Valor neto pedidos": "Net Incomes", "Cantidad en unidades(pedidos)": "Unit_Sold"})

# %%
df_bw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 37614 entries, 0 to 37613
# Data columns (total 5 columns):
# Reference                         37614 non-null int64
# Name                              37614 non-null object
# Date                              37614 non-null object
# Net Incomes                       37614 non-null float64
# Cantidad en unidades (pedidos)    37614 non-null int64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 1.7+ MB

# %%
df_bw["Date"] = pd.to_datetime(df_bw["Date"], format = "%d.%m.%Y")

# %%
df_bw["Reference"] = df_bw["Reference"].apply(str)

# %%
df_bw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 37614 entries, 0 to 37613
# Data columns (total 5 columns):
# Reference                         37614 non-null object
# Name                              37614 non-null object
# Date                              37614 non-null datetime64[ns]
# Net Incomes                       37614 non-null float64
# Cantidad en unidades (pedidos)    37614 non-null int64
# dtypes: datetime64[ns](1), float64(1), int64(1), object(2)
# memory usage: 1.7+ MB

# %%
#create some data with Names column
#data = pd.DataFrame({'Names': ['Joe', 'John', 'Jasper', 'Jez'] *4, 'Ob1' : np.random.rand(16), 'Ob2' : np.random.rand(16)})

#create unique list of names
#UniqueNames = data.Names.unique()
referencess = df_bw['Reference'].unique().tolist()

#create a data frame dictionary to store your data frames
DataFrameDict = {elem : pd.DataFrame for elem in referencess}

for key in DataFrameDict.keys():
    DataFrameDict[key] = df_bw[:][df_bw.Reference == key]

# %%
DataFrameDict['4623']
# Out:
#   Reference                                    Name       Date  Net Incomes  \
# 0      4623  ESPEJO PUERTA "LCC" BLANCO POLIETILENO 2017-09-11        18.93
# 1      4623  ESPEJO PUERTA "LCC" BLANCO POLIETILENO 2017-09-21        18.93
# 2      4623  ESPEJO PUERTA "LCC" BLANCO POLIETILENO 2017-10-08        16.08
# 3      4623  ESPEJO PUERTA "LCC" BLANCO POLIETILENO 2017-10-16        16.08
# 4      4623  ESPEJO PUERTA "LCC" BLANCO POLIETILENO 2017-10-21        16.08
#
#    Cantidad en unidades (pedidos)
# 0                               1
# 1                               1
# 2                               1
# 3                               1
# 4                               1

# %%
path = "/home/miguel/my_project_python/my_project_env/tfm/datasets"
os.chdir(path)

# %%
df_reference_url = pd.read_csv("references_url.csv", sep='\t')
column_interest_reference = ["Reference"]
df_reference_url = df_reference_url[column_interest_reference]

# %%
df_reference_url.head(5)
# Out:
#    Reference
# 0     122532
# 1      51148
# 2      51149
# 3      51136
# 4      51140

# %%
df_reference_url.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 1 columns):
# Reference    50 non-null int64
# dtypes: int64(1)
# memory usage: 480.0 bytes

# %%
lista = df_reference_url.apply(str)

# %%
lista = df_reference_url["Reference"].apply(str)
c = lista.values.tolist()

# %%
for i in range(len(c)):
    df_test = DataFrameDict[c[i]]
    file = c[i]
    
    path = "/home/miguel/my_project_python/my_project_env/tfm/datasets/bw/original_data"
    os.chdir(path)
    
    df_test.to_csv(file)

# %%
df_top_50 = pd.read_csv("101318", sep=",", error_bad_lines=True)

# %%
df_top_50
# Out:
#     Unnamed: 0  Reference                         Name        Date  \
# 0        21074     101318  SILLA MARRÓN PU/METAL SALÓN  2017-10-05
# 1        21075     101318  SILLA MARRÓN PU/METAL SALÓN  2017-10-12
# 2        21076     101318  SILLA MARRÓN PU/METAL SALÓN  2017-10-15
# 3        21077     101318  SILLA MARRÓN PU/METAL SALÓN  2018-02-06
# 4        21078     101318  SILLA MARRÓN PU/METAL SALÓN  2018-02-22
# 5        21079     101318  SILLA MARRÓN PU/METAL SALÓN  2018-02-26
# 6        21080     101318  SILLA MARRÓN PU/METAL SALÓN  2018-03-31
# 7        21081     101318  SILLA MARRÓN PU/METAL SALÓN  2018-04-22
# 8        21082     101318  SILLA MARRÓN PU/METAL SALÓN  2018-04-26
# 9        21083     101318  SILLA MARRÓN PU/METAL SALÓN  2018-05-08
# 10       21084     101318  SILLA MARRÓN PU/METAL SALÓN  2018-07-10
# 11       21085     101318  SILLA MARRÓN PU/METAL SALÓN  2018-08-01
# 12       21086     101318  SILLA MARRÓN PU/METAL SALÓN  2018-10-21
# 13       21087     101318  SILLA MARRÓN PU/METAL SALÓN  2018-10-29
# 14       21088     101318  SILLA MARRÓN PU/METAL SALÓN  2018-11-01
# 15       21089     101318  SILLA MARRÓN PU/METAL SALÓN  2018-11-06
# 16       21090     101318  SILLA MARRÓN PU/METAL SALÓN  2018-11-09
# 17       21091     101318  SILLA MARRÓN PU/METAL SALÓN  2018-11-16
# 18       21092     101318  SILLA MARRÓN PU/METAL SALÓN  2018-11-20
# 19       21093     101318  SILLA MARRÓN PU/METAL SALÓN  2018-11-21
# 20       21094     101318  SILLA MARRÓN PU/METAL SALÓN  2018-11-23
# 21       21095     101318  SILLA MARRÓN PU/METAL SALÓN  2018-11-24
# 22       21096     101318  SILLA MARRÓN PU/METAL SALÓN  2018-11-26
# 23       21097     101318  SILLA MARRÓN PU/METAL SALÓN  2018-12-03
# 24       21098     101318  SILLA MARRÓN PU/METAL SALÓN  2018-12-08
# 25       21099     101318  SILLA MARRÓN PU/METAL SALÓN  2018-12-25
# 26       21100     101318  SILLA MARRÓN PU/METAL SALÓN  2019-01-08
# 27       21101     101318  SILLA MARRÓN PU/METAL SALÓN  2019-01-09
# 28       21102     101318  SILLA MARRÓN PU/METAL SALÓN  2019-01-13
# 29       21103     101318  SILLA MARRÓN PU/METAL SALÓN  2019-01-16
# 30       21104     101318  SILLA MARRÓN PU/METAL SALÓN  2019-01-17
#
#     Net Incomes  Cantidad en unidades (pedidos)
# 0        151.53                               3
# 1        118.85                               2
# 2        202.05                               4
# 3         44.55                               1
# 4        237.69                               4
# 5        118.84                               2
# 6        237.69                               4
# 7        118.84                               2
# 8        118.84                               2
# 9        356.53                               6
# 10       237.69                               4
# 11        59.42                               1
# 12        59.42                               1
# 13        59.42                               1
# 14       178.26                               3
# 15        59.42                               1
# 16       237.69                               4
# 17       320.88                               6
# 18       427.76                               8
# 19       106.94                               2
# 20       267.35                               5
# 21       427.77                               8
# 22       374.30                               7
# 23       356.53                               6
# 24       213.92                               4
# 25       118.84                               2
# 26       106.94                               2
# 27       160.41                               3
# 28       106.94                               2
# 29       320.82                               6
# 30       213.88                               4

# %%
#queda arreglar arriba todo
#hacer funciones

#cruzar datadate como en C04 EN pageview_missing_values
# y enviar a transform data

#hacer lo mismo con adwords (dos archivos)

#luego hace falta media movil

#y algoritmos...
